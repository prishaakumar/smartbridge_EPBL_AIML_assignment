# %%
#datatypes: int, float, complex, list, tuple, str, set, dict, bool
int
float 
complex
list 
tuple 
str 
set 
dict
bool

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
x=-10
print(abs(x)) #calculate absolute value 
print(int(7.89))#removes decimal
# Out:
# 10
# 7

# %%
help(float)
# Out:
# Help on class float in module builtins:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
# ...

# %%
y=-5.67
print(abs(y)) # return absolute value 
print(round(4.56781,3))#rounds off to 3 decimal places
# Out:
# 5.67
# 4.568

# %%
help(complex)
# Out:
# Help on class complex in module builtins:
#
# class complex(object)
#  |  complex(real=0, imag=0)
#  |
#  |  Create a complex number from a real part and an optional imaginary part.
#  |
#  |  This is equivalent to (real + imag*1j) where imag defaults to 0.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __complex__(self, /)
#  |      Convert this value to exact type complex.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Convert to a string according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
# ...

# %%
z=complex(5,3)
print(z.real)# prints real part
print(z.imag)# prints imaginary part
# Out:
# 5.0
# 3.0

# %%
lst = [10, 20, 30, 40]
print(lst)
lst.append(50) 
print(lst)# Adds an element at the end
lst.insert(2, 25) #adds element on 2nd position
print(lst)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 50]
# [10, 20, 25, 30, 40, 50]

# %%
tup = (5, 10, 15, 10)
print(tup.count(10))  # 2 -> Counts occurrences of 10
print(tup.index(15))  # 2 -> Returns index of 15
# Out:
# 2
# 2

# %%
s = "Hello, Python!"
print(s.upper())  # 'HELLO, PYTHON!' -> Converts to uppercase
print(s.lower())  # 'hello, python!' -> Converts to lowercase
print(s.replace("Python", "World"))
# Out:
# HELLO, PYTHON!
# hello, python!
# Hello, World!
